# %% [markdown]
# Here we tried to modify our decoding schemes:
#
# 1. We try to convert our multiclass to binary (Generating our I1 matrices)
# 2. Try new splitting schemes (RepeatedStratifiedKFold)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
# !pip install --no-index scikit-learn seaborn
# Out:
# Looking in links: /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/x86-64-v3, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/generic, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/generic/scikit_learn-1.6.1+computecanada-cp311-cp311-linux_x86_64.whl
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/seaborn-0.13.2+computecanada-py3-none-any.whl
# Requirement already satisfied: numpy>=1.19.5 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from scikit-learn) (1.26.4+computecanada)
# Requirement already satisfied: scipy>=1.6.0 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from scikit-learn) (1.15.1+computecanada)
# Requirement already satisfied: joblib>=1.2.0 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from scikit-learn) (1.4.2+computecanada)
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/threadpoolctl-3.6.0+computecanada-py3-none-any.whl (from scikit-learn)
# Requirement already satisfied: pandas>=1.2 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from seaborn) (2.2.3+computecanada)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from seaborn) (3.10.0+computecanada)
# Requirement already satisfied: contourpy>=1.0.1 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1+computecanada)
# Requirement already satisfied: cycler>=0.10 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1+computecanada)
# Requirement already satisfied: fonttools>=4.22.0 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0+computecanada)
# Requirement already satisfied: kiwisolver>=1.3.1 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8+computecanada)
# Requirement already satisfied: packaging>=20.0 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2+computecanada)
# Requirement already satisfied: pillow>=8 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0+computecanada)
# Requirement already satisfied: pyparsing>=2.3.1 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1+computecanada)
# Requirement already satisfied: python-dateutil>=2.7 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0+computecanada)
# Requirement already satisfied: pytz>=2020.1 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.1+computecanada)
# Requirement already satisfied: tzdata>=2022.7 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.1+computecanada)
# Requirement already satisfied: six>=1.5 in /localscratch/soroush1.41475611.0/env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0+computecanada)
# Installing collected packages: threadpoolctl, scikit-learn, seaborn
# Successfully installed scikit-learn-1.6.1+computecanada seaborn-0.13.2+computecanada threadpoolctl-3.6.0+computecanada

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from scipy.stats import zscore

from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import accuracy_score

from clean_functions import load_neural_data, make_a_plot_beautiful, transpose_neural_data, select_contents, generate_times, get_percent_correct_from_proba

lbls_order = ['bear', 'elephant', 'person', 'car', 'dog', 'apple', 'chair', 'plane', 'bird', 'zebra']

# %% [markdown]
# # Load Data

# %%
# Load the neural data
neural_data_path = "./data/mag_wm_data.mat"
contents = [f"r{i}" for i in range(1, 7)]

neural_data = load_neural_data(file_path=neural_data_path, contents=contents)

# preprocess neural data
neural_data = transpose_neural_data(neural_data) # reps, imgs, ns, tb

# %% [markdown]
# ## Preprocess Data to prepare them for training

# %%
# load labels
lbls = pd.read_csv("/home/soroush1/projects/def-kohitij/soroush1/WM_age_of_ultron/data/hvm200/working_memory_images_labels.csv")
lbls = lbls.values

task = "active"
delay = 400
content = select_contents(delay=delay, task=task)
neural_ml_data = np.nanmean(neural_data[content], axis=0) # taking avg over reps

# select one time bins
neural_ml_data = np.nanmean(neural_ml_data[:, :, 2:6], axis=2) # taking avg over time bins 60-180ms
neural_ml_data = zscore(neural_ml_data, axis=1, ddof=1) # apply zscore on each columns (neural sites)

print(f"X: {neural_ml_data.shape}")
print(f"y: {lbls.shape}")

def get_data(task: str, delay: int, timebins = None):

    # load labels
    lbls = pd.read_csv("/home/soroush1/projects/def-kohitij/soroush1/WM_age_of_ultron/data/hvm200/working_memory_images_labels.csv")
    lbls = lbls.values

    # select appropiate data
    content = select_contents(delay=delay, task=task)
    neural_ml_data = np.nanmean(neural_data[content], axis=0) # taking avg over reps

    # select time bins
    if timebins is None:  
        neural_ml_data = np.nanmean(neural_ml_data[:, :, :], axis=2) # taking avg over time bins 60-180ms

    if isinstance(timebins, int):
        neural_ml_data = neural_ml_data[:, :, timebins]

    if isinstance(timebins, list):
        neural_ml_data = np.nanmean(neural_ml_data[:, :, timebins[0]:timebins[1]], axis=2)

    neural_ml_data = zscore(neural_ml_data, axis=1, ddof=1) # apply zscore on each columns (neural sites)

    return neural_ml_data, lbls
# Out:
# X: (200, 192)
# y: (200, 1)

# %% [markdown]
# ## Prepare model

# %%
# Define the classifier with equivalent parameters
clf = SGDClassifier(
    loss="log",            # Logistic regression
    penalty="l2",          # Ridge regression (L2 regularization)
    alpha="auto",
    max_iter=20000,        # Iteration limit
    tol=None,              # No early stopping
    learning_rate="optimal"
)

multi_clf = OneVsRestClassifier(clf)

# Initialize Kfold
kf = StratifiedKFold(n_splits=2, shuffle=True, random_state=42)

def get_model():
    clf = SGDClassifier(
    loss="log_loss",            # Logistic regression
    penalty="l2",          # Ridge regression (L2 regularization)
    alpha=0.0001,
    max_iter=20000,        # Iteration limit
    tol=None,              # No early stopping
    learning_rate="optimal"
    )
    
    return OneVsRestClassifier(clf)

# %% [markdown]
# ## Training Process

# %%
accs = np.zeros(2) # number of kfold

for fold, (tr_idx, val_idx) in enumerate(kf.split(neural_ml_data, lbls)):
    print(f"Fold {fold + 1}")
    tr = neural_ml_data[tr_idx]
    y_tr = lbls[tr_idx]
    val = neural_ml_data[val_idx]
    y_val = lbls[val_idx]

    print(f"\ty_tr: {np.unique(y_tr)} {y_tr.shape}")
    print(f"\ty_val: {np.unique(y_val)} {y_val.shape}")

    multi_clf = get_model()

    multi_clf.fit(tr, y_tr)
    y_preds = multi_clf.predict(val)
    accs[fold] = accuracy_score(y_val, y_preds)
    
accs
# Out:
# Fold 1
# 	y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 	y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# Fold 2
# 	y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 	y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# array([0.46, 0.49])

# %% [markdown]
# # Running Decoder over the neural data

# %%
total_trials = 200
indices = np.arange(0, total_trials)
indices[indices == test_indices[0]]

# %%
timebins = 41
bins_dur = 30
nfolds = 5

task = "active"
delay = 400

test_indices = np.load("kfolds_test_indices.npy", allow_pickle=True)
total_trials = 200
indices = np.arange(0, total_trials)

i1s = np.zeros((timebins, test_indices.shape[0], test_indices.shape[1], len(lbls_order))) # folds, imgs, unique_labels
accs = np.zeros((timebins, test_indices.shape[0])) # timebins, folds
for i in range(timebins):
    print(f"time bins: {bins_dur*i}ms")
    X, y = get_data(task=task, delay=delay, timebins=i)
    print(f"\tX: {X.shape}")
    
    for fold, test_idx in enumerate(test_indices):
        print(f"\t\tfold {fold + 1}")
        
        # Explicitly convert test_idx to integers
        test_idx_int = test_idx.astype(np.int64)
        
        # Create boolean mask
        test_mask = np.zeros(shape=(total_trials), dtype=bool)
        
        # Use the converted indices
        test_mask[test_idx_int] = True
        
        tr_idx = indices[~test_mask]
        val_idx = indices[test_mask]
        print(f"{tr_idx[:10] =  }")
        print(f"{val_idx[:10] = }")
                
        tr = X[tr_idx]
        y_tr = y[tr_idx]
        val = X[val_idx]
        y_val = y[val_idx]

        print(f"{tr.mean()}")
        print(f"{val.mean()}")
        
        print(f"\t\t\ty_tr: {np.unique(y_tr)} {y_tr.shape}")
        print(f"\t\t\ty_val: {np.unique(y_val)} {y_val.shape}")

        multi_clf = get_model()
    
        multi_clf.fit(tr, y_tr)
        y_preds = multi_clf.predict(val)
        y_preds_prob = multi_clf.predict_proba(val)
        i1_metric = get_percent_correct_from_proba(y_preds_prob, y_val, lbls_order)
        print(f"behavioral_acc: {np.nanmean(i1_metric)} +/- {np.nanstd(i1_metric)}")
        print(f"acc: {accuracy_score(y_val, y_preds)}")
        i1s[i,fold] = i1_metric
        accs[i,fold] = accuracy_score(y_val, y_preds)
# Out:
# time bins: 0ms
# 	X: (200, 192)
# 		fold 1
# tr_idx[:10] =  array([ 1,  2,  6,  8,  9, 10, 13, 15, 17, 18])
# val_idx[:10] = array([ 0,  3,  4,  5,  7, 11, 12, 14, 16, 19])
# -7.771561172376097e-18
# 2.960594732333751e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4801495983320828 +/- 0.4962278625562313
# acc: 0.06
# 		fold 2
# tr_idx[:10] =  array([ 0,  3,  4,  5,  7, 11, 12, 14, 16, 19])
# val_idx[:10] = array([ 1,  2,  6,  8,  9, 10, 13, 15, 17, 18])
# 2.960594732333751e-18
# -7.771561172376097e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4980695172872232 +/- 0.49710753492820065
# acc: 0.08
# 		fold 3
# tr_idx[:10] =  array([ 2,  4,  6,  7,  8, 11, 13, 14, 16, 18])
# val_idx[:10] = array([ 0,  1,  3,  5,  9, 10, 12, 15, 17, 19])
# -3.23815048849004e-18
# -3.0531133177191805e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5243269410510579 +/- 0.4935920885327913
# acc: 0.06
# 		fold 4
# tr_idx[:10] =  array([ 0,  1,  3,  5,  9, 10, 12, 15, 17, 19])
# val_idx[:10] = array([ 2,  4,  6,  7,  8, 11, 13, 14, 16, 18])
# -3.0531133177191805e-18
# -3.23815048849004e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4928450065522731 +/- 0.4967176896220388
# acc: 0.08
# 		fold 5
# tr_idx[:10] =  array([ 0,  1,  2,  3,  6,  7,  9, 10, 14, 18])
# val_idx[:10] = array([ 4,  5,  8, 11, 12, 13, 15, 16, 17, 19])
# 2.220446049250313e-18
# -5.551115123125783e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5037142223749148 +/- 0.4962065732127182
# acc: 0.19
# 		fold 6
# tr_idx[:10] =  array([ 4,  5,  8, 11, 12, 13, 15, 16, 17, 19])
# val_idx[:10] = array([ 0,  1,  2,  3,  6,  7,  9, 10, 14, 18])
# -5.551115123125783e-18
# 2.220446049250313e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.48852362974662317 +/- 0.49765018478936485
# acc: 0.08
# 		fold 7
# tr_idx[:10] =  array([ 2,  4,  7,  8,  9, 10, 12, 14, 16, 19])
# val_idx[:10] = array([ 0,  1,  3,  5,  6, 11, 13, 15, 17, 18])
# -9.436895709313831e-18
# 6.0137080500529315e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.49705024186780355 +/- 0.4967606406887189
# acc: 0.06
# 		fold 8
# tr_idx[:10] =  array([ 0,  1,  3,  5,  6, 11, 13, 15, 17, 18])
# val_idx[:10] = array([ 2,  4,  7,  8,  9, 10, 12, 14, 16, 19])
# 6.0137080500529315e-18
# -9.436895709313831e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4998792445565144 +/- 0.49676189590474606
# acc: 0.09
# 		fold 9
# tr_idx[:10] =  array([ 0,  1,  3,  5,  8,  9, 14, 15, 16, 17])
# val_idx[:10] = array([ 2,  4,  6,  7, 10, 11, 12, 13, 18, 19])
# -2.960594732333751e-18
# 3.7007434154171887e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4928382594284112 +/- 0.4957426872670467
# acc: 0.12
# 		fold 10
# tr_idx[:10] =  array([ 2,  4,  6,  7, 10, 11, 12, 13, 18, 19])
# val_idx[:10] = array([ 0,  1,  3,  5,  8,  9, 14, 15, 16, 17])
# 3.7007434154171887e-19
# -2.960594732333751e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5001321025117212 +/- 0.4949554592774976
# acc: 0.1
# 		fold 11
# tr_idx[:10] =  array([ 2,  3,  4,  5,  6,  9, 10, 13, 17, 19])
# val_idx[:10] = array([ 0,  1,  7,  8, 11, 12, 14, 15, 16, 18])
# 4.2558549277297664e-18
# -8.974302782386681e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4392314876273305 +/- 0.49269650634195106
# acc: 0.09
# 		fold 12
# tr_idx[:10] =  array([ 0,  1,  7,  8, 11, 12, 14, 15, 16, 18])
# val_idx[:10] = array([ 2,  3,  4,  5,  6,  9, 10, 13, 17, 19])
# -8.974302782386681e-18
# 4.2558549277297664e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4741200333788248 +/- 0.4958921551930964
# acc: 0.05
# 		fold 13
# tr_idx[:10] =  array([ 3,  4,  6,  7,  8,  9, 13, 14, 15, 16])
# val_idx[:10] = array([ 0,  1,  2,  5, 10, 11, 12, 17, 18, 19])
# -7.771561172376097e-18
# 8.326672684688674e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4524115811936834 +/- 0.49554959433101153
# acc: 0.07
# 		fold 14
# tr_idx[:10] =  array([ 0,  1,  2,  5, 10, 11, 12, 17, 18, 19])
# val_idx[:10] = array([ 3,  4,  6,  7,  8,  9, 13, 14, 15, 16])
# 8.326672684688674e-19
# -7.771561172376097e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5268675798879324 +/- 0.49423537249745153
# acc: 0.14
# 		fold 15
# tr_idx[:10] =  array([ 1,  3,  4,  6,  8,  9, 13, 14, 16, 19])
# val_idx[:10] = array([ 0,  2,  5,  7, 10, 11, 12, 15, 17, 18])
# 1.2027416100105863e-18
# -7.216449660063518e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.48070670827017414 +/- 0.497117672467217
# acc: 0.08
# 		fold 16
# tr_idx[:10] =  array([ 0,  2,  5,  7, 10, 11, 12, 15, 17, 18])
# val_idx[:10] = array([ 1,  3,  4,  6,  8,  9, 13, 14, 16, 19])
# -7.216449660063518e-18
# 1.2027416100105863e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5080029103551708 +/- 0.49818797265157483
# acc: 0.08
# 		fold 17
# tr_idx[:10] =  array([ 1,  3,  4,  6,  7,  8,  9, 13, 14, 16])
# val_idx[:10] = array([ 0,  2,  5, 10, 11, 12, 15, 17, 18, 19])
# -2.960594732333751e-18
# -4.070817756958907e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5054959992831555 +/- 0.4961069639124867
# acc: 0.13
# 		fold 18
# tr_idx[:10] =  array([ 0,  2,  5, 10, 11, 12, 15, 17, 18, 19])
# val_idx[:10] = array([ 1,  3,  4,  6,  7,  8,  9, 13, 14, 16])
# -4.070817756958907e-18
# -2.960594732333751e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.48717188920165944 +/- 0.49604699893577103
# acc: 0.1
# 		fold 19
# tr_idx[:10] =  array([ 3,  4,  8, 10, 12, 13, 14, 15, 16, 19])
# val_idx[:10] = array([ 0,  1,  2,  5,  6,  7,  9, 11, 17, 18])
# -7.401486830834377e-18
# 1.3877787807814458e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5149586014475857 +/- 0.4980133616336256
# acc: 0.09
# 		fold 20
# tr_idx[:10] =  array([ 0,  1,  2,  5,  6,  7,  9, 11, 17, 18])
# val_idx[:10] = array([ 3,  4,  8, 10, 12, 13, 14, 15, 16, 19])
# 1.3877787807814458e-18
# -7.401486830834377e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.47605894555885925 +/- 0.49634677012351647
# acc: 0.07
# 		fold 21
# tr_idx[:10] =  array([ 0,  1,  3,  4,  6, 11, 14, 16, 18, 19])
# val_idx[:10] = array([ 2,  5,  7,  8,  9, 10, 12, 13, 15, 17])
# -3.23815048849004e-18
# -3.7007434154171887e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5043178731819143 +/- 0.49658497444005795
# acc: 0.09
# 		fold 22
# tr_idx[:10] =  array([ 2,  5,  7,  8,  9, 10, 12, 13, 15, 17])
# val_idx[:10] = array([ 0,  1,  3,  4,  6, 11, 14, 16, 18, 19])
# -3.7007434154171887e-19
# -3.23815048849004e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5091269763620132 +/- 0.49711188213468177
# acc: 0.12
# 		fold 23
# tr_idx[:10] =  array([ 0,  2,  3,  5,  7, 11, 13, 14, 16, 19])
# val_idx[:10] = array([ 1,  4,  6,  8,  9, 10, 12, 15, 17, 18])
# -4.903485025427775e-18
# -3.3306690738754695e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.45967786111481795 +/- 0.49525784546745166
# acc: 0.1
# 		fold 24
# tr_idx[:10] =  array([ 1,  4,  6,  8,  9, 10, 12, 15, 17, 18])
# val_idx[:10] = array([ 0,  2,  3,  5,  7, 11, 13, 14, 16, 19])
# -3.3306690738754695e-18
# -4.903485025427775e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5208272682796793 +/- 0.49652825572371584
# acc: 0.13
# 		fold 25
# tr_idx[:10] =  array([ 4,  5,  7,  8, 10, 11, 12, 13, 14, 17])
# val_idx[:10] = array([ 0,  1,  2,  3,  6,  9, 15, 16, 18, 19])
# -1.4062824978585317e-17
# 6.29126380620922e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4848268235778402 +/- 0.49572266045235003
# acc: 0.09
# 		fold 26
# tr_idx[:10] =  array([ 0,  1,  2,  3,  6,  9, 15, 16, 18, 19])
# val_idx[:10] = array([ 4,  5,  7,  8, 10, 11, 12, 13, 14, 17])
# 6.29126380620922e-18
# -1.4062824978585317e-17
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5319536334873807 +/- 0.4951998133653607
# acc: 0.13
# 		fold 27
# tr_idx[:10] =  array([ 0,  4,  7,  8, 10, 13, 15, 16, 18, 19])
# val_idx[:10] = array([ 1,  2,  3,  5,  6,  9, 11, 12, 14, 17])
# 1.8503717077085944e-19
# -7.123931074678087e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5348254239988803 +/- 0.49589205222585425
# acc: 0.09
# 		fold 28
# tr_idx[:10] =  array([ 1,  2,  3,  5,  6,  9, 11, 12, 14, 17])
# val_idx[:10] = array([ 0,  4,  7,  8, 10, 13, 15, 16, 18, 19])
# -7.123931074678087e-18
# 1.8503717077085944e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5007734304563004 +/- 0.4942113437946237
# acc: 0.13
# 		fold 29
# tr_idx[:10] =  array([ 0,  2,  3,  5,  7, 10, 16, 17, 18, 19])
# val_idx[:10] = array([ 1,  4,  6,  8,  9, 11, 12, 13, 14, 15])
# -8.141635513917815e-18
# 2.590520390792032e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5397413060255994 +/- 0.49497763520070526
# acc: 0.07
# 		fold 30
# tr_idx[:10] =  array([ 1,  4,  6,  8,  9, 11, 12, 13, 14, 15])
# val_idx[:10] = array([ 0,  2,  3,  5,  7, 10, 16, 17, 18, 19])
# 2.590520390792032e-18
# -8.141635513917815e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.472379012998097 +/- 0.4930020029967268
# acc: 0.11
# 		fold 31
# tr_idx[:10] =  array([ 0,  1,  5,  8, 11, 13, 14, 15, 18, 19])
# val_idx[:10] = array([ 2,  3,  4,  6,  7,  9, 10, 12, 16, 17])
# -2.960594732333751e-18
# -4.070817756958907e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5310586653077316 +/- 0.4948097029976852
# acc: 0.06
# 		fold 32
# tr_idx[:10] =  array([ 2,  3,  4,  6,  7,  9, 10, 12, 16, 17])
# val_idx[:10] = array([ 0,  1,  5,  8, 11, 13, 14, 15, 18, 19])
# -4.070817756958907e-18
# -2.960594732333751e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5246794966843179 +/- 0.4961284170720543
# acc: 0.1
# 		fold 33
# tr_idx[:10] =  array([ 0,  1,  2,  4, 11, 12, 13, 14, 15, 17])
# val_idx[:10] = array([ 3,  5,  6,  7,  8,  9, 10, 16, 18, 19])
# -6.38378239159465e-18
# 0.0
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5262145334981189 +/- 0.49490494986498035
# acc: 0.13
# 		fold 34
# tr_idx[:10] =  array([ 3,  5,  6,  7,  8,  9, 10, 16, 18, 19])
# val_idx[:10] = array([ 0,  1,  2,  4, 11, 12, 13, 14, 15, 17])
# 0.0
# -6.38378239159465e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4702355882163497 +/- 0.49493659250612815
# acc: 0.06
# 		fold 35
# tr_idx[:10] =  array([ 0,  6,  9, 10, 13, 14, 16, 17, 18, 19])
# val_idx[:10] = array([ 1,  2,  3,  4,  5,  7,  8, 11, 12, 15])
# -6.753856733136369e-18
# -1.7578531223231647e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.47505526474669535 +/- 0.4949933879956271
# acc: 0.12
# 		fold 36
# tr_idx[:10] =  array([ 1,  2,  3,  4,  5,  7,  8, 11, 12, 15])
# val_idx[:10] = array([ 0,  6,  9, 10, 13, 14, 16, 17, 18, 19])
# -1.7578531223231647e-18
# -6.753856733136369e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5083450648963234 +/- 0.49584474177037524
# acc: 0.08
# 		fold 37
# tr_idx[:10] =  array([ 0,  2,  3,  4,  5,  6, 10, 14, 17, 18])
# val_idx[:10] = array([ 1,  7,  8,  9, 11, 12, 13, 15, 16, 19])
# -4.718447854656916e-18
# -2.4054832200211726e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.521547656054889 +/- 0.4958377681573757
# acc: 0.07
# 		fold 38
# tr_idx[:10] =  array([ 1,  7,  8,  9, 11, 12, 13, 15, 16, 19])
# val_idx[:10] = array([ 0,  2,  3,  4,  5,  6, 10, 14, 17, 18])
# -2.4054832200211726e-18
# -4.718447854656916e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4885887526946147 +/- 0.4927337134189562
# acc: 0.15
# 		fold 39
# tr_idx[:10] =  array([ 1,  2,  5,  8, 14, 15, 16, 17, 18, 19])
# val_idx[:10] = array([ 0,  3,  4,  6,  7,  9, 10, 11, 12, 13])
# -1.7578531223231647e-18
# -3.885780586188048e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4548443699630787 +/- 0.494001254564545
# acc: 0.14
# 		fold 40
# tr_idx[:10] =  array([ 0,  3,  4,  6,  7,  9, 10, 11, 12, 13])
# val_idx[:10] = array([ 1,  2,  5,  8, 14, 15, 16, 17, 18, 19])
# -3.885780586188048e-18
# -1.7578531223231647e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4953329277381089 +/- 0.49652891955105927
# acc: 0.09
# time bins: 30ms
# 	X: (200, 192)
# 		fold 1
# tr_idx[:10] =  array([ 1,  2,  6,  8,  9, 10, 13, 15, 17, 18])
# val_idx[:10] = array([ 0,  3,  4,  5,  7, 11, 12, 14, 16, 19])
# 3.793262000802618e-18
# -1.1102230246251566e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5427310016714493 +/- 0.4901325654565923
# acc: 0.12
# 		fold 2
# tr_idx[:10] =  array([ 0,  3,  4,  5,  7, 11, 12, 14, 16, 19])
# val_idx[:10] = array([ 1,  2,  6,  8,  9, 10, 13, 15, 17, 18])
# -1.1102230246251566e-18
# 3.793262000802618e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5072357096210663 +/- 0.49359266860000256
# acc: 0.08
# 		fold 3
# tr_idx[:10] =  array([ 2,  4,  6,  7,  8, 11, 13, 14, 16, 18])
# val_idx[:10] = array([ 0,  1,  3,  5,  9, 10, 12, 15, 17, 19])
# -3.0531133177191805e-18
# 7.771561172376097e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5096358310089709 +/- 0.49376441896431245
# acc: 0.08
# 		fold 4
# tr_idx[:10] =  array([ 0,  1,  3,  5,  9, 10, 12, 15, 17, 19])
# val_idx[:10] = array([ 2,  4,  6,  7,  8, 11, 13, 14, 16, 18])
# 7.771561172376097e-18
# -3.0531133177191805e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.49666004409702347 +/- 0.4948495012727237
# acc: 0.11
# 		fold 5
# tr_idx[:10] =  array([ 0,  1,  2,  3,  6,  7,  9, 10, 14, 18])
# val_idx[:10] = array([ 4,  5,  8, 11, 12, 13, 15, 16, 17, 19])
# 4.625929269271486e-19
# 4.718447854656916e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5193935640276294 +/- 0.49351382714501224
# acc: 0.06
# 		fold 6
# tr_idx[:10] =  array([ 4,  5,  8, 11, 12, 13, 15, 16, 17, 19])
# val_idx[:10] = array([ 0,  1,  2,  3,  6,  7,  9, 10, 14, 18])
# 4.718447854656916e-18
# 4.625929269271486e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.49098196699223706 +/- 0.494340386007273
# acc: 0.1
# 		fold 7
# tr_idx[:10] =  array([ 2,  4,  7,  8,  9, 10, 12, 14, 16, 19])
# val_idx[:10] = array([ 0,  1,  3,  5,  6, 11, 13, 15, 17, 18])
# 8.049116928532384e-18
# -9.251858538542972e-20
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4757216391106006 +/- 0.4925144982383737
# acc: 0.07
# 		fold 8
# tr_idx[:10] =  array([ 0,  1,  3,  5,  6, 11, 13, 15, 17, 18])
# val_idx[:10] = array([ 2,  4,  7,  8,  9, 10, 12, 14, 16, 19])
# -9.251858538542972e-20
# 8.049116928532384e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.544181126321979 +/- 0.49008654071521784
# acc: 0.09
# 		fold 9
# tr_idx[:10] =  array([ 0,  1,  3,  5,  8,  9, 14, 15, 16, 17])
# val_idx[:10] = array([ 2,  4,  6,  7, 10, 11, 12, 13, 18, 19])
# -2.0354088784794537e-18
# 5.458596537740353e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5235947984071105 +/- 0.4932243048415631
# acc: 0.09
# 		fold 10
# tr_idx[:10] =  array([ 2,  4,  6,  7, 10, 11, 12, 13, 18, 19])
# val_idx[:10] = array([ 0,  1,  3,  5,  8,  9, 14, 15, 16, 17])
# 5.458596537740353e-18
# -2.0354088784794537e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5103877800928637 +/- 0.4953944309853471
# acc: 0.04
# 		fold 11
# tr_idx[:10] =  array([ 2,  3,  4,  5,  6,  9, 10, 13, 17, 19])
# val_idx[:10] = array([ 0,  1,  7,  8, 11, 12, 14, 15, 16, 18])
# 5.736152293896642e-18
# -2.960594732333751e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.48237040196713926 +/- 0.4936436777790852
# acc: 0.12
# 		fold 12
# tr_idx[:10] =  array([ 0,  1,  7,  8, 11, 12, 14, 15, 16, 18])
# val_idx[:10] = array([ 2,  3,  4,  5,  6,  9, 10, 13, 17, 19])
# -2.960594732333751e-18
# 5.736152293896642e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5372575916681083 +/- 0.4909364255880071
# acc: 0.05
# 		fold 13
# tr_idx[:10] =  array([ 3,  4,  6,  7,  8,  9, 13, 14, 15, 16])
# val_idx[:10] = array([ 0,  1,  2,  5, 10, 11, 12, 17, 18, 19])
# 6.47630097698008e-19
# 5.921189464667502e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5208377019254892 +/- 0.4927759350376205
# acc: 0.1
# 		fold 14
# tr_idx[:10] =  array([ 0,  1,  2,  5, 10, 11, 12, 17, 18, 19])
# val_idx[:10] = array([ 3,  4,  6,  7,  8,  9, 13, 14, 15, 16])
# 5.921189464667502e-18
# 6.47630097698008e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.47114299705911367 +/- 0.4939045891666271
# acc: 0.07
# 		fold 15
# tr_idx[:10] =  array([ 1,  3,  4,  6,  8,  9, 13, 14, 16, 19])
# val_idx[:10] = array([ 0,  2,  5,  7, 10, 11, 12, 15, 17, 18])
# -1.572815951552305e-18
# 6.47630097698008e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5168977477700548 +/- 0.49180945999687137
# acc: 0.02
# 		fold 16
# tr_idx[:10] =  array([ 0,  2,  5,  7, 10, 11, 12, 15, 17, 18])
# val_idx[:10] = array([ 1,  3,  4,  6,  8,  9, 13, 14, 16, 19])
# 6.47630097698008e-18
# -1.572815951552305e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.46790161658133483 +/- 0.489912897193523
# acc: 0.07
# 		fold 17
# tr_idx[:10] =  array([ 1,  3,  4,  6,  7,  8,  9, 13, 14, 16])
# val_idx[:10] = array([ 0,  2,  5, 10, 11, 12, 15, 17, 18, 19])
# 1.7578531223231647e-18
# 4.348373513115197e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4956462233784602 +/- 0.4936014279708613
# acc: 0.09
# 		fold 18
# tr_idx[:10] =  array([ 0,  2,  5, 10, 11, 12, 15, 17, 18, 19])
# val_idx[:10] = array([ 1,  3,  4,  6,  7,  8,  9, 13, 14, 16])
# 4.348373513115197e-18
# 1.7578531223231647e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5044112046903226 +/- 0.4948113734154218
# acc: 0.05
# 		fold 19
# tr_idx[:10] =  array([ 3,  4,  8, 10, 12, 13, 14, 15, 16, 19])
# val_idx[:10] = array([ 0,  1,  2,  5,  6,  7,  9, 11, 17, 18])
# 2.7755575615628915e-18
# -1.2027416100105863e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.46198289125277997 +/- 0.49280746692365
# acc: 0.05
# 		fold 20
# tr_idx[:10] =  array([ 0,  1,  2,  5,  6,  7,  9, 11, 17, 18])
# val_idx[:10] = array([ 3,  4,  8, 10, 12, 13, 14, 15, 16, 19])
# -1.2027416100105863e-18
# 2.7755575615628915e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5067693609960875 +/- 0.4931550945828755
# acc: 0.13
# 		fold 21
# tr_idx[:10] =  array([ 0,  1,  3,  4,  6, 11, 14, 16, 18, 19])
# val_idx[:10] = array([ 2,  5,  7,  8,  9, 10, 12, 13, 15, 17])
# 6.0137080500529315e-18
# -2.220446049250313e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4915972496053521 +/- 0.49285161249955145
# acc: 0.13
# 		fold 22
# tr_idx[:10] =  array([ 2,  5,  7,  8,  9, 10, 12, 13, 15, 17])
# val_idx[:10] = array([ 0,  1,  3,  4,  6, 11, 14, 16, 18, 19])
# -2.220446049250313e-18
# 6.0137080500529315e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4720818864020818 +/- 0.4919307186558826
# acc: 0.1
# 		fold 23
# tr_idx[:10] =  array([ 0,  2,  3,  5,  7, 11, 13, 14, 16, 19])
# val_idx[:10] = array([ 1,  4,  6,  8,  9, 10, 12, 15, 17, 18])
# 3.4231876592608994e-18
# 5.181040781584064e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5049740056232368 +/- 0.49404557807609817
# acc: 0.1
# 		fold 24
# tr_idx[:10] =  array([ 1,  4,  6,  8,  9, 10, 12, 15, 17, 18])
# val_idx[:10] = array([ 0,  2,  3,  5,  7, 11, 13, 14, 16, 19])
# 5.181040781584064e-18
# 3.4231876592608994e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.48775051076552217 +/- 0.49505590370290664
# acc: 0.08
# 		fold 25
# tr_idx[:10] =  array([ 4,  5,  7,  8, 10, 11, 12, 13, 14, 17])
# val_idx[:10] = array([ 0,  1,  2,  3,  6,  9, 15, 16, 18, 19])
# 6.29126380620922e-18
# -3.7007434154171887e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.47091473765327124 +/- 0.49175668712331855
# acc: 0.09
# 		fold 26
# tr_idx[:10] =  array([ 0,  1,  2,  3,  6,  9, 15, 16, 18, 19])
# val_idx[:10] = array([ 4,  5,  7,  8, 10, 11, 12, 13, 14, 17])
# -3.7007434154171887e-19
# 6.29126380620922e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.48265196686882506 +/- 0.4947783244417518
# acc: 0.05
# 		fold 27
# tr_idx[:10] =  array([ 0,  4,  7,  8, 10, 13, 15, 16, 18, 19])
# val_idx[:10] = array([ 1,  2,  3,  5,  6,  9, 11, 12, 14, 17])
# 3.23815048849004e-18
# 1.7578531223231647e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5053897288040828 +/- 0.49393863269481497
# acc: 0.03
# 		fold 28
# tr_idx[:10] =  array([ 1,  2,  3,  5,  6,  9, 11, 12, 14, 17])
# val_idx[:10] = array([ 0,  4,  7,  8, 10, 13, 15, 16, 18, 19])
# 1.7578531223231647e-18
# 3.23815048849004e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.47358393768784574 +/- 0.49380106597969947
# acc: 0.14
# 		fold 29
# tr_idx[:10] =  array([ 0,  2,  3,  5,  7, 10, 16, 17, 18, 19])
# val_idx[:10] = array([ 1,  4,  6,  8,  9, 11, 12, 13, 14, 15])
# 5.921189464667502e-18
# 2.590520390792032e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5211650602898839 +/- 0.4949822592921778
# acc: 0.08
# 		fold 30
# tr_idx[:10] =  array([ 1,  4,  6,  8,  9, 11, 12, 13, 14, 15])
# val_idx[:10] = array([ 0,  2,  3,  5,  7, 10, 16, 17, 18, 19])
# 2.590520390792032e-18
# 5.921189464667502e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4541278679574542 +/- 0.4915223711476825
# acc: 0.09
# 		fold 31
# tr_idx[:10] =  array([ 0,  1,  5,  8, 11, 13, 14, 15, 18, 19])
# val_idx[:10] = array([ 2,  3,  4,  6,  7,  9, 10, 12, 16, 17])
# 9.25185853854297e-18
# -1.0177044392397268e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5112495901218167 +/- 0.49450330443453094
# acc: 0.08
# 		fold 32
# tr_idx[:10] =  array([ 2,  3,  4,  6,  7,  9, 10, 12, 16, 17])
# val_idx[:10] = array([ 0,  1,  5,  8, 11, 13, 14, 15, 18, 19])
# -1.0177044392397268e-18
# 9.25185853854297e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5337490935102034 +/- 0.4936540527918755
# acc: 0.08
# 		fold 33
# tr_idx[:10] =  array([ 0,  1,  2,  4, 11, 12, 13, 14, 15, 17])
# val_idx[:10] = array([ 3,  5,  6,  7,  8,  9, 10, 16, 18, 19])
# 9.89948863624098e-18
# -5.181040781584064e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5853381791287322 +/- 0.4844912247390449
# acc: 0.07
# 		fold 34
# tr_idx[:10] =  array([ 3,  5,  6,  7,  8,  9, 10, 16, 18, 19])
# val_idx[:10] = array([ 0,  1,  2,  4, 11, 12, 13, 14, 15, 17])
# -5.181040781584064e-18
# 9.89948863624098e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5007496079811053 +/- 0.4903763386746279
# acc: 0.06
# 		fold 35
# tr_idx[:10] =  array([ 0,  6,  9, 10, 13, 14, 16, 17, 18, 19])
# val_idx[:10] = array([ 1,  2,  3,  4,  5,  7,  8, 11, 12, 15])
# 6.5688195623655095e-18
# -1.0177044392397268e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5411313605639957 +/- 0.49199231045322217
# acc: 0.09
# 		fold 36
# tr_idx[:10] =  array([ 1,  2,  3,  4,  5,  7,  8, 11, 12, 15])
# val_idx[:10] = array([ 0,  6,  9, 10, 13, 14, 16, 17, 18, 19])
# -1.0177044392397268e-18
# 6.5688195623655095e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4596852211523869 +/- 0.4933690257978145
# acc: 0.1
# 		fold 37
# tr_idx[:10] =  array([ 0,  2,  3,  4,  5,  6, 10, 14, 17, 18])
# val_idx[:10] = array([ 1,  7,  8,  9, 11, 12, 13, 15, 16, 19])
# -3.3306690738754695e-18
# 9.714451465470119e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.48604207191875104 +/- 0.4950020033971457
# acc: 0.09
# 		fold 38
# tr_idx[:10] =  array([ 1,  7,  8,  9, 11, 12, 13, 15, 16, 19])
# val_idx[:10] = array([ 0,  2,  3,  4,  5,  6, 10, 14, 17, 18])
# 9.714451465470119e-18
# -3.3306690738754695e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.44840709910118615 +/- 0.4900618349132024
# acc: 0.12
# 		fold 39
# tr_idx[:10] =  array([ 1,  2,  5,  8, 14, 15, 16, 17, 18, 19])
# val_idx[:10] = array([ 0,  3,  4,  6,  7,  9, 10, 11, 12, 13])
# 7.401486830834377e-18
# -2.498001805406602e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5319513619738725 +/- 0.49376386117694027
# acc: 0.09
# 		fold 40
# tr_idx[:10] =  array([ 0,  3,  4,  6,  7,  9, 10, 11, 12, 13])
# val_idx[:10] = array([ 1,  2,  5,  8, 14, 15, 16, 17, 18, 19])
# -2.498001805406602e-18
# 7.401486830834377e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5065618594581748 +/- 0.4940725213399454
# acc: 0.07
# time bins: 60ms
# 	X: (200, 192)
# 		fold 1
# tr_idx[:10] =  array([ 1,  2,  6,  8,  9, 10, 13, 15, 17, 18])
# val_idx[:10] = array([ 0,  3,  4,  5,  7, 11, 12, 14, 16, 19])
# -2.4054832200211726e-18
# -2.498001805406602e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5102542403349604 +/- 0.44876038494560194
# acc: 0.1
# 		fold 2
# tr_idx[:10] =  array([ 0,  3,  4,  5,  7, 11, 12, 14, 16, 19])
# val_idx[:10] = array([ 1,  2,  6,  8,  9, 10, 13, 15, 17, 18])
# -2.498001805406602e-18
# -2.4054832200211726e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5153915275690023 +/- 0.4519050534084237
# acc: 0.14
# 		fold 3
# tr_idx[:10] =  array([ 2,  4,  6,  7,  8, 11, 13, 14, 16, 18])
# val_idx[:10] = array([ 0,  1,  3,  5,  9, 10, 12, 15, 17, 19])
# -2.0354088784794537e-18
# -8.326672684688674e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.43767137845829335 +/- 0.4430801907203083
# acc: 0.09
# 		fold 4
# tr_idx[:10] =  array([ 0,  1,  3,  5,  9, 10, 12, 15, 17, 19])
# val_idx[:10] = array([ 2,  4,  6,  7,  8, 11, 13, 14, 16, 18])
# -8.326672684688674e-19
# -2.0354088784794537e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5126340595052825 +/- 0.4450616381463062
# acc: 0.08
# 		fold 5
# tr_idx[:10] =  array([ 0,  1,  2,  3,  6,  7,  9, 10, 14, 18])
# val_idx[:10] = array([ 4,  5,  8, 11, 12, 13, 15, 16, 17, 19])
# -3.3306690738754695e-18
# -5.551115123125783e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.46109635025977375 +/- 0.44894188004999225
# acc: 0.1
# 		fold 6
# tr_idx[:10] =  array([ 4,  5,  8, 11, 12, 13, 15, 16, 17, 19])
# val_idx[:10] = array([ 0,  1,  2,  3,  6,  7,  9, 10, 14, 18])
# -5.551115123125783e-19
# -3.3306690738754695e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.48833282660832383 +/- 0.45122190569831716
# acc: 0.13
# 		fold 7
# tr_idx[:10] =  array([ 2,  4,  7,  8,  9, 10, 12, 14, 16, 19])
# val_idx[:10] = array([ 0,  1,  3,  5,  6, 11, 13, 15, 17, 18])
# -2.4054832200211726e-18
# -2.590520390792032e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5081675289247286 +/- 0.45115458373854644
# acc: 0.1
# 		fold 8
# tr_idx[:10] =  array([ 0,  1,  3,  5,  6, 11, 13, 15, 17, 18])
# val_idx[:10] = array([ 2,  4,  7,  8,  9, 10, 12, 14, 16, 19])
# -2.590520390792032e-18
# -2.4054832200211726e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4409244537350368 +/- 0.4495218831249076
# acc: 0.16
# 		fold 9
# tr_idx[:10] =  array([ 0,  1,  3,  5,  8,  9, 14, 15, 16, 17])
# val_idx[:10] = array([ 2,  4,  6,  7, 10, 11, 12, 13, 18, 19])
# -8.789265611615822e-18
# 3.654484122724473e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4841921588754516 +/- 0.4509324652717216
# acc: 0.14
# 		fold 10
# tr_idx[:10] =  array([ 2,  4,  6,  7, 10, 11, 12, 13, 18, 19])
# val_idx[:10] = array([ 0,  1,  3,  5,  8,  9, 14, 15, 16, 17])
# 3.654484122724473e-18
# -8.789265611615822e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.43506550107548553 +/- 0.4464136358900121
# acc: 0.16
# 		fold 11
# tr_idx[:10] =  array([ 2,  3,  4,  5,  6,  9, 10, 13, 17, 19])
# val_idx[:10] = array([ 0,  1,  7,  8, 11, 12, 14, 15, 16, 18])
# -1.61907524424502e-17
# 1.0824674490095277e-17
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.45882317613684376 +/- 0.45287442812783935
# acc: 0.12
# 		fold 12
# tr_idx[:10] =  array([ 0,  1,  7,  8, 11, 12, 14, 15, 16, 18])
# val_idx[:10] = array([ 2,  3,  4,  5,  6,  9, 10, 13, 17, 19])
# 1.0824674490095277e-17
# -1.61907524424502e-17
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5081571601748747 +/- 0.44947490512999455
# acc: 0.18
# 		fold 13
# tr_idx[:10] =  array([ 3,  4,  6,  7,  8,  9, 13, 14, 15, 16])
# val_idx[:10] = array([ 0,  1,  2,  5, 10, 11, 12, 17, 18, 19])
# 1.3507713466272739e-17
# -1.924386576016938e-17
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.43665319298455013 +/- 0.4517525483646563
# acc: 0.19
# 		fold 14
# tr_idx[:10] =  array([ 0,  1,  2,  5, 10, 11, 12, 17, 18, 19])
# val_idx[:10] = array([ 3,  4,  6,  7,  8,  9, 13, 14, 15, 16])
# -1.924386576016938e-17
# 1.3507713466272739e-17
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5653003010111217 +/- 0.44189262231970833
# acc: 0.16
# 		fold 15
# tr_idx[:10] =  array([ 1,  3,  4,  6,  8,  9, 13, 14, 16, 19])
# val_idx[:10] = array([ 0,  2,  5,  7, 10, 11, 12, 15, 17, 18])
# -6.5688195623655095e-18
# 1.6653345369377347e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4787369023254145 +/- 0.4534952239218451
# acc: 0.1
# 		fold 16
# tr_idx[:10] =  array([ 0,  2,  5,  7, 10, 11, 12, 15, 17, 18])
# val_idx[:10] = array([ 1,  3,  4,  6,  8,  9, 13, 14, 16, 19])
# 1.6653345369377347e-18
# -6.5688195623655095e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4855678147652294 +/- 0.45117411569291943
# acc: 0.12
# 		fold 17
# tr_idx[:10] =  array([ 1,  3,  4,  6,  7,  8,  9, 13, 14, 16])
# val_idx[:10] = array([ 0,  2,  5, 10, 11, 12, 15, 17, 18, 19])
# -1.295260195396016e-18
# -3.793262000802618e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4318112356286453 +/- 0.44172483050694217
# acc: 0.09
# 		fold 18
# tr_idx[:10] =  array([ 0,  2,  5, 10, 11, 12, 15, 17, 18, 19])
# val_idx[:10] = array([ 1,  3,  4,  6,  7,  8,  9, 13, 14, 16])
# -3.793262000802618e-18
# -1.295260195396016e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.49993059643048987 +/- 0.449823730256151
# acc: 0.14
# 		fold 19
# tr_idx[:10] =  array([ 3,  4,  8, 10, 12, 13, 14, 15, 16, 19])
# val_idx[:10] = array([ 0,  1,  2,  5,  6,  7,  9, 11, 17, 18])
# -4.348373513115197e-18
# 9.251858538542972e-20
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.46508114451417604 +/- 0.4512914114652871
# acc: 0.14
# 		fold 20
# tr_idx[:10] =  array([ 0,  1,  2,  5,  6,  7,  9, 11, 17, 18])
# val_idx[:10] = array([ 3,  4,  8, 10, 12, 13, 14, 15, 16, 19])
# 9.251858538542972e-20
# -4.348373513115197e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.46262959720522245 +/- 0.45283950889433316
# acc: 0.12
# 		fold 21
# tr_idx[:10] =  array([ 0,  1,  3,  4,  6, 11, 14, 16, 18, 19])
# val_idx[:10] = array([ 2,  5,  7,  8,  9, 10, 12, 13, 15, 17])
# -1.2027416100105863e-17
# 1.1564823173178714e-17
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4931846965320244 +/- 0.4515817874808597
# acc: 0.15
# 		fold 22
# tr_idx[:10] =  array([ 2,  5,  7,  8,  9, 10, 12, 13, 15, 17])
# val_idx[:10] = array([ 0,  1,  3,  4,  6, 11, 14, 16, 18, 19])
# 1.1564823173178714e-17
# -1.2027416100105863e-17
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4989394583416499 +/- 0.45739344731449216
# acc: 0.15
# 		fold 23
# tr_idx[:10] =  array([ 0,  2,  3,  5,  7, 11, 13, 14, 16, 19])
# val_idx[:10] = array([ 1,  4,  6,  8,  9, 10, 12, 15, 17, 18])
# -5.273559366969494e-18
# -3.7007434154171887e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4742808958195051 +/- 0.44482303551547286
# acc: 0.2
# 		fold 24
# tr_idx[:10] =  array([ 1,  4,  6,  8,  9, 10, 12, 15, 17, 18])
# val_idx[:10] = array([ 0,  2,  3,  5,  7, 11, 13, 14, 16, 19])
# -3.7007434154171887e-19
# -5.273559366969494e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4659371311768938 +/- 0.45691759399196147
# acc: 0.18
# 		fold 25
# tr_idx[:10] =  array([ 4,  5,  7,  8, 10, 11, 12, 13, 14, 17])
# val_idx[:10] = array([ 0,  1,  2,  3,  6,  9, 15, 16, 18, 19])
# -7.123931074678087e-18
# 1.7578531223231647e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.47603329233510394 +/- 0.4582156131517307
# acc: 0.15
# 		fold 26
# tr_idx[:10] =  array([ 0,  1,  2,  3,  6,  9, 15, 16, 18, 19])
# val_idx[:10] = array([ 4,  5,  7,  8, 10, 11, 12, 13, 14, 17])
# 1.7578531223231647e-18
# -7.123931074678087e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5248598979920334 +/- 0.44944611661847805
# acc: 0.17
# 		fold 27
# tr_idx[:10] =  array([ 0,  4,  7,  8, 10, 13, 15, 16, 18, 19])
# val_idx[:10] = array([ 1,  2,  3,  5,  6,  9, 11, 12, 14, 17])
# -1.1102230246251566e-18
# -5.736152293896642e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# ...
# 2.960594732333751e-18
# 3.3306690738754695e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5001593124506687 +/- 0.4917854470407741
# acc: 0.1
# time bins: 1080ms
# 	X: (200, 192)
# 		fold 1
# tr_idx[:10] =  array([ 1,  2,  6,  8,  9, 10, 13, 15, 17, 18])
# val_idx[:10] = array([ 0,  3,  4,  5,  7, 11, 12, 14, 16, 19])
# 5.181040781584064e-18
# -4.163336342344337e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5151136182932664 +/- 0.4917117118518943
# acc: 0.13
# 		fold 2
# tr_idx[:10] =  array([ 0,  3,  4,  5,  7, 11, 12, 14, 16, 19])
# val_idx[:10] = array([ 1,  2,  6,  8,  9, 10, 13, 15, 17, 18])
# -4.163336342344337e-18
# 5.181040781584064e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.483638724498055 +/- 0.492914400677339
# acc: 0.1
# 		fold 3
# tr_idx[:10] =  array([ 2,  4,  6,  7,  8, 11, 13, 14, 16, 18])
# val_idx[:10] = array([ 0,  1,  3,  5,  9, 10, 12, 15, 17, 19])
# -6.106226635438361e-18
# 3.515706244646329e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4953164098190462 +/- 0.4897546546670581
# acc: 0.1
# 		fold 4
# tr_idx[:10] =  array([ 0,  1,  3,  5,  9, 10, 12, 15, 17, 19])
# val_idx[:10] = array([ 2,  4,  6,  7,  8, 11, 13, 14, 16, 18])
# 3.515706244646329e-18
# -6.106226635438361e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5543362150514478 +/- 0.487971495811257
# acc: 0.1
# 		fold 5
# tr_idx[:10] =  array([ 0,  1,  2,  3,  6,  7,  9, 10, 14, 18])
# val_idx[:10] = array([ 4,  5,  8, 11, 12, 13, 15, 16, 17, 19])
# 2.498001805406602e-18
# -4.625929269271485e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5036831606083217 +/- 0.49025595999135113
# acc: 0.09
# 		fold 6
# tr_idx[:10] =  array([ 4,  5,  8, 11, 12, 13, 15, 16, 17, 19])
# val_idx[:10] = array([ 0,  1,  2,  3,  6,  7,  9, 10, 14, 18])
# -4.625929269271485e-18
# 2.498001805406602e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5404836810250446 +/- 0.4898181991850381
# acc: 0.09
# 		fold 7
# tr_idx[:10] =  array([ 2,  4,  7,  8,  9, 10, 12, 14, 16, 19])
# val_idx[:10] = array([ 0,  1,  3,  5,  6, 11, 13, 15, 17, 18])
# -5.736152293896642e-18
# 4.2558549277297664e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5380022797382225 +/- 0.4880658684362481
# acc: 0.12
# 		fold 8
# tr_idx[:10] =  array([ 0,  1,  3,  5,  6, 11, 13, 15, 17, 18])
# val_idx[:10] = array([ 2,  4,  7,  8,  9, 10, 12, 14, 16, 19])
# 4.2558549277297664e-18
# -5.736152293896642e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5177648295873012 +/- 0.49089929178460096
# acc: 0.16
# 		fold 9
# tr_idx[:10] =  array([ 0,  1,  3,  5,  8,  9, 14, 15, 16, 17])
# val_idx[:10] = array([ 2,  4,  6,  7, 10, 11, 12, 13, 18, 19])
# 5.181040781584064e-18
# -4.996003610813204e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5171013592681529 +/- 0.48969204777751607
# acc: 0.06
# 		fold 10
# tr_idx[:10] =  array([ 2,  4,  6,  7, 10, 11, 12, 13, 18, 19])
# val_idx[:10] = array([ 0,  1,  3,  5,  8,  9, 14, 15, 16, 17])
# -4.996003610813204e-18
# 5.181040781584064e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5100189355676218 +/- 0.49155365295959097
# acc: 0.1
# 		fold 11
# tr_idx[:10] =  array([ 2,  3,  4,  5,  6,  9, 10, 13, 17, 19])
# val_idx[:10] = array([ 0,  1,  7,  8, 11, 12, 14, 15, 16, 18])
# -1.6653345369377347e-18
# 4.810966440042345e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5290911447011478 +/- 0.4871834486500128
# acc: 0.11
# 		fold 12
# tr_idx[:10] =  array([ 0,  1,  7,  8, 11, 12, 14, 15, 16, 18])
# val_idx[:10] = array([ 2,  3,  4,  5,  6,  9, 10, 13, 17, 19])
# 4.810966440042345e-18
# -1.6653345369377347e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.536400852177758 +/- 0.48925356801120995
# acc: 0.11
# 		fold 13
# tr_idx[:10] =  array([ 3,  4,  6,  7,  8,  9, 13, 14, 15, 16])
# val_idx[:10] = array([ 0,  1,  2,  5, 10, 11, 12, 17, 18, 19])
# 5.551115123125783e-19
# -7.401486830834377e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.513333419964968 +/- 0.48871726042906005
# acc: 0.14
# 		fold 14
# tr_idx[:10] =  array([ 0,  1,  2,  5, 10, 11, 12, 17, 18, 19])
# val_idx[:10] = array([ 3,  4,  6,  7,  8,  9, 13, 14, 15, 16])
# -7.401486830834377e-19
# 5.551115123125783e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.498488717205705 +/- 0.48854724224762075
# acc: 0.1
# 		fold 15
# tr_idx[:10] =  array([ 1,  3,  4,  6,  8,  9, 13, 14, 16, 19])
# val_idx[:10] = array([ 0,  2,  5,  7, 10, 11, 12, 15, 17, 18])
# -7.586524001605236e-18
# 7.031412489292659e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5268492324531852 +/- 0.49249458551091174
# acc: 0.09
# 		fold 16
# tr_idx[:10] =  array([ 0,  2,  5,  7, 10, 11, 12, 15, 17, 18])
# val_idx[:10] = array([ 1,  3,  4,  6,  8,  9, 13, 14, 16, 19])
# 7.031412489292659e-18
# -7.586524001605236e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5300852597253376 +/- 0.49260539945892334
# acc: 0.13
# 		fold 17
# tr_idx[:10] =  array([ 1,  3,  4,  6,  7,  8,  9, 13, 14, 16])
# val_idx[:10] = array([ 0,  2,  5, 10, 11, 12, 15, 17, 18, 19])
# -6.47630097698008e-18
# 5.273559366969494e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.49887398688237733 +/- 0.4897130128807292
# acc: 0.11
# 		fold 18
# tr_idx[:10] =  array([ 0,  2,  5, 10, 11, 12, 15, 17, 18, 19])
# val_idx[:10] = array([ 1,  3,  4,  6,  7,  8,  9, 13, 14, 16])
# 5.273559366969494e-18
# -6.47630097698008e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5363735012643928 +/- 0.49009239615094674
# acc: 0.14
# 		fold 19
# tr_idx[:10] =  array([ 3,  4,  8, 10, 12, 13, 14, 15, 16, 19])
# val_idx[:10] = array([ 0,  1,  2,  5,  6,  7,  9, 11, 17, 18])
# 2.868076146948321e-18
# -1.295260195396016e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.4836867303111737 +/- 0.4898020293615693
# acc: 0.1
# 		fold 20
# tr_idx[:10] =  array([ 0,  1,  2,  5,  6,  7,  9, 11, 17, 18])
# val_idx[:10] = array([ 3,  4,  8, 10, 12, 13, 14, 15, 16, 19])
# -1.295260195396016e-18
# 2.868076146948321e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.49942127759369415 +/- 0.4900149012261978
# acc: 0.1
# 		fold 21
# tr_idx[:10] =  array([ 0,  1,  3,  4,  6, 11, 14, 16, 18, 19])
# val_idx[:10] = array([ 2,  5,  7,  8,  9, 10, 12, 13, 15, 17])
# -7.401486830834377e-19
# -1.6653345369377347e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5274531643308749 +/- 0.49173032645668086
# acc: 0.13
# 		fold 22
# tr_idx[:10] =  array([ 2,  5,  7,  8,  9, 10, 12, 13, 15, 17])
# val_idx[:10] = array([ 0,  1,  3,  4,  6, 11, 14, 16, 18, 19])
# -1.6653345369377347e-18
# -7.401486830834377e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5255669683299955 +/- 0.4911895825002912
# acc: 0.14
# 		fold 23
# tr_idx[:10] =  array([ 0,  2,  3,  5,  7, 11, 13, 14, 16, 19])
# val_idx[:10] = array([ 1,  4,  6,  8,  9, 10, 12, 15, 17, 18])
# -1.1102230246251566e-18
# -2.1279274638648832e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5120345579000903 +/- 0.48948061395766784
# acc: 0.13
# 		fold 24
# tr_idx[:10] =  array([ 1,  4,  6,  8,  9, 10, 12, 15, 17, 18])
# val_idx[:10] = array([ 0,  2,  3,  5,  7, 11, 13, 14, 16, 19])
# -2.1279274638648832e-18
# -1.1102230246251566e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5611740789187113 +/- 0.4847764964509515
# acc: 0.11
# 		fold 25
# tr_idx[:10] =  array([ 4,  5,  7,  8, 10, 11, 12, 13, 14, 17])
# val_idx[:10] = array([ 0,  1,  2,  3,  6,  9, 15, 16, 18, 19])
# -4.625929269271485e-18
# 3.0531133177191805e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5153639327039796 +/- 0.48721563623031555
# acc: 0.08
# 		fold 26
# tr_idx[:10] =  array([ 0,  1,  2,  3,  6,  9, 15, 16, 18, 19])
# val_idx[:10] = array([ 4,  5,  7,  8, 10, 11, 12, 13, 14, 17])
# 3.0531133177191805e-18
# -4.625929269271485e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.49132868877160984 +/- 0.491963620935542
# acc: 0.06
# 		fold 27
# tr_idx[:10] =  array([ 0,  4,  7,  8, 10, 13, 15, 16, 18, 19])
# val_idx[:10] = array([ 1,  2,  3,  5,  6,  9, 11, 12, 14, 17])
# -5.551115123125783e-18
# 5.366077952354923e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5002374746915887 +/- 0.4892795830889405
# acc: 0.1
# 		fold 28
# tr_idx[:10] =  array([ 1,  2,  3,  5,  6,  9, 11, 12, 14, 17])
# val_idx[:10] = array([ 0,  4,  7,  8, 10, 13, 15, 16, 18, 19])
# 5.366077952354923e-18
# -5.551115123125783e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5122499036410181 +/- 0.48871251328871324
# acc: 0.09
# 		fold 29
# tr_idx[:10] =  array([ 0,  2,  3,  5,  7, 10, 16, 17, 18, 19])
# val_idx[:10] = array([ 1,  4,  6,  8,  9, 11, 12, 13, 14, 15])
# -3.3306690738754695e-18
# -2.220446049250313e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.48910751207330433 +/- 0.49257583856324866
# acc: 0.14
# 		fold 30
# tr_idx[:10] =  array([ 1,  4,  6,  8,  9, 11, 12, 13, 14, 15])
# val_idx[:10] = array([ 0,  2,  3,  5,  7, 10, 16, 17, 18, 19])
# -2.220446049250313e-18
# -3.3306690738754695e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5261470823844787 +/- 0.48957640772333805
# acc: 0.1
# 		fold 31
# tr_idx[:10] =  array([ 0,  1,  5,  8, 11, 13, 14, 15, 18, 19])
# val_idx[:10] = array([ 2,  3,  4,  6,  7,  9, 10, 12, 16, 17])
# -4.625929269271485e-18
# 5.921189464667502e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.49710306792883935 +/- 0.49116550112595997
# acc: 0.13
# 		fold 32
# tr_idx[:10] =  array([ 2,  3,  4,  6,  7,  9, 10, 12, 16, 17])
# val_idx[:10] = array([ 0,  1,  5,  8, 11, 13, 14, 15, 18, 19])
# 5.921189464667502e-18
# -4.625929269271485e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5192472323310955 +/- 0.48723174396372937
# acc: 0.11
# 		fold 33
# tr_idx[:10] =  array([ 0,  1,  2,  4, 11, 12, 13, 14, 15, 17])
# val_idx[:10] = array([ 3,  5,  6,  7,  8,  9, 10, 16, 18, 19])
# 2.960594732333751e-18
# -1.8503717077085944e-19
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5159563311698079 +/- 0.48887366902255064
# acc: 0.04
# 		fold 34
# tr_idx[:10] =  array([ 3,  5,  6,  7,  8,  9, 10, 16, 18, 19])
# val_idx[:10] = array([ 0,  1,  2,  4, 11, 12, 13, 14, 15, 17])
# -1.8503717077085944e-19
# 2.960594732333751e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# behavioral_acc: 0.5402472120538999 +/- 0.4894281741690991
# acc: 0.08
# 		fold 35
# tr_idx[:10] =  array([ 0,  6,  9, 10, 13, 14, 16, 17, 18, 19])
# val_idx[:10] = array([ 1,  2,  3,  4,  5,  7,  8, 11, 12, 15])
# -2.0354088784794537e-18
# 1.0177044392397268e-18
# 			y_tr: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)
# 			y_val: ['apple' 'bear' 'bird' 'car' 'chair' 'dog' 'elephant' 'person' 'plane'
#  'zebra'] (100, 1)

# %% [markdown]
# # Plot Decoder Results

# %%
times = generate_times(0, 1200, 30)
fig, ax = plt.subplots(figsize=(7, 7))

for delay in [400, 800, 1200]:
    decoder_results = np.load(f"decoding_accuracy_{delay}ms.npy")
    mean = decoder_results.mean(axis=1) #
    sd = decoder_results.std(axis=1, ddof=1)
    se = sd / np.sqrt(len(mean))

    # Plot mean response
    ax.plot(times, mean, linewidth=2, label=f"{delay}", marker="o", linestyle="--")
    
    # Add SE as a shaded region
    ax.fill_between(times, mean - se, mean + se, alpha=0.3, label=f"{delay}")

# Add vertical dashed lines at 60ms and 180ms
# ax.axvline(x=60, linestyle="-.", color="green", linewidth=1.5, label="Event at 60ms")
# ax.axvline(x=180, linestyle="-.", color="green", linewidth=1.5, label="Event at 180ms")

# Set baseline
ax.axhline(y=0.1, linestyle="-.", color="b", linewidth=1.5, label="baseline")

make_a_plot_beautiful(ax)

# Labels and legend
ax.set_xlabel("Time (ms)")
ax.set_ylabel("Decoder Accuracy")
ax.legend()

plt.show()
